# %% [markdown]
# # Normalize susbsistence grids
# Grids from the raw data have values of "number of harvesters". This notebook opens those output tifs, converts the data to be from 0-1, and writes a new file.

# %%
import rasterio
import shapely
import geopandas as gpd
import numpy as np
import os
import glob
from tqdm import trange
import matplotlib.pyplot as plt

# %%
in_dir = '../../outputs/OSRA/subsistence-actual/'
out_dir = '../../outputs/OSRA/subsistence-normalized/'

# %% [markdown]
# ## Get normalization values
# We're looking to normalize each community, but we want to retain relative importance of resources within each community. For this work, we normalize each community by the maximum number of harvesters calculated across all months and resources in that community.

# %%
def get_max(filename):
    
    with rasterio.open(filename) as dataset:
        return np.max(dataset.read(1))

# %%
kaktovik_max = get_max(in_dir + 'community/kaktovik-allresources-allmonths.tif')
print('Kaktovik max: ', kaktovik_max)
nuiqsut_max = get_max(in_dir + 'community/nuiqsut-allresources-allmonths.tif')
print('Nuiqsut max: ', nuiqsut_max)
utqiagvik_max = get_max(in_dir + 'community/utqiagvik-allresources-allmonths.tif')
print('Utqiagvik max: ', utqiagvik_max)
# Out:
# Kaktovik max:  30
# Nuiqsut max:  24
# Utqiagvik max:  66

# %% [markdown]
# ## Open files and normalize

# %%
def normalize_tif(infile, outfile, norm_value):
    
        with rasterio.open(infile) as dataset:
            profile = dataset.profile
            band1 = dataset.read(1)

        
        # Change ints to normalized floats
        band1 = band1/norm_value
        profile.update(dtype = rasterio.float64)

        with rasterio.open(outfile, 'w', **profile) as destination:
            destination.write(band1.astype(np.float64), 1)

# %%
def normalize_list(search_string, norm_value, overwrite=True):

    filenames = sorted(glob.glob(os.path.join(in_dir, search_string + '*.tif')))
    
    t1 = trange(len(filenames))

    for i in t1:
        basename = os.path.basename(filenames[i])
        
        t1.set_description(basename)

        splits = str.split(filenames[i], '/')
        outfilename = os.path.join(out_dir, basename)

        # check for file and overwrite status
        if not os.path.isfile(outfilename) or overwrite:
            normalize_tif(filenames[i], outfilename, norm_value)

# %%
normalize_list('kaktovik', kaktovik_max)
# Out:
#   0%|          | 0/144 [00:00<?, ?it/s]
#
#
#
# kaktovik-arcticcisco-april.tif:   1%|          | 1/144 [00:02<05:55,  2.49s/it]
#
#
#
# kaktovik-arcticcisco-august.tif:   1%|▏         | 2/144 [00:04<05:32,  2.34s/it]
#
#
#
# kaktovik-arcticcisco-december.tif:   2%|▏         | 3/144 [00:06<05:15,  2.24s/it]
#
#
#
# kaktovik-arcticcisco-february.tif:   3%|▎         | 4/144 [00:08<05:03,  2.17s/it]
#
#
#
# kaktovik-arcticcisco-january.tif:   3%|▎         | 5/144 [00:10<04:54,  2.12s/it]
#
#
#
# kaktovik-arcticcisco-july.tif:   4%|▍         | 6/144 [00:12<04:47,  2.08s/it]
#
#
#
# kaktovik-arcticcisco-june.tif:   5%|▍         | 7/144 [00:14<04:42,  2.06s/it]
#
#
#
# kaktovik-arcticcisco-march.tif:   6%|▌         | 8/144 [00:16<04:37,  2.04s/it]
#
#
#
# kaktovik-arcticcisco-may.tif:   6%|▋         | 9/144 [00:18<04:34,  2.03s/it]
#
#
#
# kaktovik-arcticcisco-november.tif:   7%|▋         | 10/144 [00:20<04:30,  2.02s/it]
#
#
#
# kaktovik-arcticcisco-october.tif:   8%|▊         | 11/144 [00:22<04:45,  2.14s/it]
#
#
#
# kaktovik-arcticcisco-september.tif:   8%|▊         | 12/144 [00:24<04:03,  1.84s/it]
#
#
#
# kaktovik-beardedseal-april.tif:   9%|▉         | 13/144 [00:25<03:45,  1.72s/it]
#
#
#
# kaktovik-beardedseal-august.tif:  10%|▉         | 14/144 [00:27<04:11,  1.93s/it]
#
#
#
# kaktovik-beardedseal-december.tif:  10%|█         | 15/144 [00:31<04:55,  2.29s/it]
#
#
#
# kaktovik-beardedseal-february.tif:  11%|█         | 16/144 [00:32<04:21,  2.04s/it]
#
#
#
# kaktovik-beardedseal-january.tif:  12%|█▏        | 17/144 [00:34<04:17,  2.03s/it]
#
#
#
# kaktovik-beardedseal-july.tif:  12%|█▎        | 18/144 [00:36<04:14,  2.02s/it]
#
#
#
# kaktovik-beardedseal-june.tif:  13%|█▎        | 19/144 [00:38<04:11,  2.01s/it]
#
#
#
# kaktovik-beardedseal-march.tif:  14%|█▍        | 20/144 [00:40<04:09,  2.01s/it]
#
#
#
# kaktovik-beardedseal-may.tif:  15%|█▍        | 21/144 [00:42<04:07,  2.01s/it]
#
#
#
# kaktovik-beardedseal-november.tif:  15%|█▌        | 22/144 [00:44<04:04,  2.01s/it]
#
#
#
# kaktovik-beardedseal-october.tif:  16%|█▌        | 23/144 [00:46<04:02,  2.01s/it]
#
#
#
# kaktovik-beardedseal-september.tif:  17%|█▋        | 24/144 [00:48<04:00,  2.00s/it]
#
#
#
# kaktovik-bowhead-april.tif:  17%|█▋        | 25/144 [00:50<03:58,  2.00s/it]
#
#
#
# kaktovik-bowhead-august.tif:  18%|█▊        | 26/144 [00:52<03:56,  2.00s/it]
#
#
#
# kaktovik-bowhead-december.tif:  19%|█▉        | 27/144 [00:54<03:54,  2.00s/it]
#
#
#
# kaktovik-bowhead-february.tif:  19%|█▉        | 28/144 [00:56<03:52,  2.00s/it]
#
#
#
# kaktovik-bowhead-january.tif:  20%|██        | 29/144 [00:58<03:50,  2.00s/it]
#
#
#
# kaktovik-bowhead-july.tif:  21%|██        | 30/144 [01:00<03:48,  2.00s/it]
#
#
#
# kaktovik-bowhead-june.tif:  22%|██▏       | 31/144 [01:02<03:46,  2.00s/it]
#
#
#
# kaktovik-bowhead-march.tif:  22%|██▏       | 32/144 [01:04<03:44,  2.01s/it]
#
#
#
# kaktovik-bowhead-may.tif:  23%|██▎       | 33/144 [01:06<03:42,  2.00s/it]
#
#
#
# kaktovik-bowhead-november.tif:  24%|██▎       | 34/144 [01:08<03:40,  2.00s/it]
#
#
#
# kaktovik-bowhead-october.tif:  24%|██▍       | 35/144 [01:10<03:38,  2.00s/it]
#
#
#
# kaktovik-bowhead-september.tif:  25%|██▌       | 36/144 [01:12<03:36,  2.00s/it]
#
#
#
# kaktovik-broadwhitefish-april.tif:  26%|██▌       | 37/144 [01:14<03:34,  2.00s/it]
#
#
#
# kaktovik-broadwhitefish-august.tif:  26%|██▋       | 38/144 [01:16<03:32,  2.00s/it]
#
#
#
# kaktovik-broadwhitefish-december.tif:  27%|██▋       | 39/144 [01:18<03:30,  2.00s/it]
#
#
#
# kaktovik-broadwhitefish-february.tif:  28%|██▊       | 40/144 [01:20<03:28,  2.00s/it]
#
#
#
# kaktovik-broadwhitefish-january.tif:  28%|██▊       | 41/144 [01:22<03:26,  2.00s/it]
#
#
#
# kaktovik-broadwhitefish-july.tif:  29%|██▉       | 42/144 [01:24<03:24,  2.00s/it]
#
#
#
# kaktovik-broadwhitefish-june.tif:  30%|██▉       | 43/144 [01:26<03:22,  2.00s/it]
#
#
#
# kaktovik-broadwhitefish-march.tif:  31%|███       | 44/144 [01:28<03:20,  2.00s/it]
#
#
#
# kaktovik-broadwhitefish-may.tif:  31%|███▏      | 45/144 [01:30<03:18,  2.00s/it]
#
#
#
# kaktovik-broadwhitefish-november.tif:  32%|███▏      | 46/144 [01:32<03:16,  2.00s/it]
#
#
#
# kaktovik-broadwhitefish-october.tif:  33%|███▎      | 47/144 [01:34<03:14,  2.00s/it]
#
#
#
# kaktovik-broadwhitefish-september.tif:  33%|███▎      | 48/144 [01:36<03:12,  2.00s/it]
#
#
#
# kaktovik-burbot-april.tif:  34%|███▍      | 49/144 [01:38<03:10,  2.00s/it]
#
#
#
# kaktovik-burbot-august.tif:  35%|███▍      | 50/144 [01:40<03:08,  2.00s/it]
#
#
#
# kaktovik-burbot-december.tif:  35%|███▌      | 51/144 [01:42<03:06,  2.00s/it]
#
#
#
# kaktovik-burbot-february.tif:  36%|███▌      | 52/144 [01:44<03:04,  2.00s/it]
#
#
#
# kaktovik-burbot-january.tif:  37%|███▋      | 53/144 [01:46<03:02,  2.00s/it]
#
#
#
# kaktovik-burbot-july.tif:  38%|███▊      | 54/144 [01:48<03:00,  2.00s/it]
#
#
#
# kaktovik-burbot-june.tif:  38%|███▊      | 55/144 [01:50<02:58,  2.00s/it]
#
#
#
# kaktovik-burbot-march.tif:  39%|███▉      | 56/144 [01:52<02:58,  2.03s/it]
#
#
#
# kaktovik-burbot-may.tif:  40%|███▉      | 57/144 [01:54<02:53,  1.99s/it]
#
#
#
# kaktovik-burbot-november.tif:  40%|████      | 58/144 [01:56<02:51,  2.00s/it]
#
#
#
# kaktovik-burbot-october.tif:  41%|████      | 59/144 [01:58<02:49,  2.00s/it]
#
#
#
# kaktovik-burbot-september.tif:  42%|████▏     | 60/144 [02:00<02:47,  2.00s/it]
#
#
#
# kaktovik-caribou-april.tif:  42%|████▏     | 61/144 [02:02<02:46,  2.00s/it]
#
#
#
# kaktovik-caribou-august.tif:  43%|████▎     | 62/144 [02:04<02:44,  2.00s/it]
#
#
#
# kaktovik-caribou-december.tif:  44%|████▍     | 63/144 [02:06<02:42,  2.00s/it]
#
#
#
# kaktovik-caribou-february.tif:  44%|████▍     | 64/144 [02:08<02:40,  2.00s/it]
#
#
#
# kaktovik-caribou-january.tif:  45%|████▌     | 65/144 [02:10<02:38,  2.00s/it]
#
#
#
# kaktovik-caribou-july.tif:  46%|████▌     | 66/144 [02:12<02:36,  2.00s/it]
#
#
#
# kaktovik-caribou-june.tif:  47%|████▋     | 67/144 [02:14<02:34,  2.00s/it]
#
#
#
# kaktovik-caribou-march.tif:  47%|████▋     | 68/144 [02:16<02:32,  2.00s/it]
#
#
#
# kaktovik-caribou-may.tif:  48%|████▊     | 69/144 [02:18<02:30,  2.00s/it]
#
#
#
# kaktovik-caribou-november.tif:  49%|████▊     | 70/144 [02:20<02:28,  2.00s/it]
#
#
#
# kaktovik-caribou-october.tif:  49%|████▉     | 71/144 [02:22<02:26,  2.00s/it]
#
#
#
# kaktovik-caribou-september.tif:  50%|█████     | 72/144 [02:25<02:33,  2.13s/it]
#
#
#
# kaktovik-dollyvardenchar-april.tif:  51%|█████     | 73/144 [02:28<02:52,  2.43s/it]
#
#
#
# kaktovik-dollyvardenchar-august.tif:  51%|█████▏    | 74/144 [02:29<02:29,  2.14s/it]
#
#
#
# kaktovik-dollyvardenchar-december.tif:  52%|█████▏    | 75/144 [02:31<02:24,  2.10s/it]
#
#
#
# kaktovik-dollyvardenchar-february.tif:  53%|█████▎    | 76/144 [02:33<02:20,  2.07s/it]
#
#
#
# kaktovik-dollyvardenchar-january.tif:  53%|█████▎    | 77/144 [02:35<02:17,  2.05s/it]
#
#
#
# kaktovik-dollyvardenchar-july.tif:  54%|█████▍    | 78/144 [02:37<02:14,  2.04s/it]
#
#
#
# kaktovik-dollyvardenchar-june.tif:  55%|█████▍    | 79/144 [02:39<02:11,  2.03s/it]
#
#
#
# kaktovik-dollyvardenchar-march.tif:  56%|█████▌    | 80/144 [02:41<02:09,  2.02s/it]
#
#
#
# kaktovik-dollyvardenchar-may.tif:  56%|█████▋    | 81/144 [02:43<02:06,  2.01s/it]
#
#
#
# kaktovik-dollyvardenchar-november.tif:  57%|█████▋    | 82/144 [02:45<02:04,  2.01s/it]
#
#
#
# kaktovik-dollyvardenchar-october.tif:  58%|█████▊    | 83/144 [02:47<02:02,  2.01s/it]
# kaktovik-dollyvardenchar-september.tif:  58%|█████▊    | 84/144 [02:49<02:00,  2.01s/it]
#
#
#
# kaktovik-eider-april.tif:  59%|█████▉    | 85/144 [02:51<01:58,  2.01s/it]
#
#
#
# kaktovik-eider-august.tif:  60%|█████▉    | 86/144 [02:53<01:56,  2.00s/it]
#
#
#
# kaktovik-eider-december.tif:  60%|██████    | 87/144 [02:55<01:54,  2.00s/it]
#
#
#
# kaktovik-eider-february.tif:  61%|██████    | 88/144 [02:57<01:52,  2.00s/it]
#
#
#
# kaktovik-eider-january.tif:  62%|██████▏   | 89/144 [02:59<01:50,  2.00s/it]
#
#
#
# kaktovik-eider-july.tif:  62%|██████▎   | 90/144 [02:59<01:19,  1.47s/it]
#
#
#
# kaktovik-eider-june.tif:  63%|██████▎   | 91/144 [03:01<01:22,  1.56s/it]
#
#
#
# kaktovik-eider-march.tif:  64%|██████▍   | 92/144 [03:03<01:28,  1.69s/it]
#
#
#
# kaktovik-eider-may.tif:  65%|██████▍   | 93/144 [03:05<01:31,  1.79s/it]
#
#
#
# kaktovik-eider-november.tif:  65%|██████▌   | 94/144 [03:07<01:32,  1.85s/it]
#
#
#
# kaktovik-eider-october.tif:  66%|██████▌   | 95/144 [03:09<01:32,  1.90s/it]
#
#
#
# kaktovik-eider-september.tif:  67%|██████▋   | 96/144 [03:11<01:32,  1.93s/it]
#
#
#
# kaktovik-geese-april.tif:  67%|██████▋   | 97/144 [03:13<01:31,  1.95s/it]
#
#
#
# kaktovik-geese-august.tif:  68%|██████▊   | 98/144 [03:15<01:30,  1.96s/it]
#
#
#
# kaktovik-geese-december.tif:  69%|██████▉   | 99/144 [03:17<01:28,  1.98s/it]
#
#
#
# kaktovik-geese-february.tif:  69%|██████▉   | 100/144 [03:19<01:27,  1.98s/it]
#
#
#
# kaktovik-geese-january.tif:  70%|███████   | 101/144 [03:21<01:25,  1.99s/it]
#
#
#
# kaktovik-geese-july.tif:  71%|███████   | 102/144 [03:23<01:23,  1.99s/it]
#
#
#
# kaktovik-geese-june.tif:  72%|███████▏  | 103/144 [03:25<01:21,  2.00s/it]
#
#
#
# kaktovik-geese-march.tif:  72%|███████▏  | 104/144 [03:27<01:19,  2.00s/it]
#
#
#
# kaktovik-geese-may.tif:  73%|███████▎  | 105/144 [03:29<01:18,  2.00s/it]
#
#
#
# kaktovik-geese-november.tif:  74%|███████▎  | 106/144 [03:31<01:16,  2.00s/it]
#
#
#
# kaktovik-geese-october.tif:  74%|███████▍  | 107/144 [03:33<01:14,  2.00s/it]
#
#
#
# kaktovik-geese-september.tif:  75%|███████▌  | 108/144 [03:35<01:12,  2.00s/it]
#
#
#
# kaktovik-ringedseal-april.tif:  76%|███████▌  | 109/144 [03:37<01:10,  2.00s/it]
#
#
#
# kaktovik-ringedseal-august.tif:  76%|███████▋  | 110/144 [03:39<01:08,  2.00s/it]
#
#
#
# kaktovik-ringedseal-december.tif:  77%|███████▋  | 111/144 [03:41<01:06,  2.00s/it]
#
#
#
# kaktovik-ringedseal-february.tif:  78%|███████▊  | 112/144 [03:43<01:04,  2.00s/it]
#
#
#
# kaktovik-ringedseal-january.tif:  78%|███████▊  | 113/144 [03:45<01:01,  2.00s/it]
#
#
#
# kaktovik-ringedseal-july.tif:  79%|███████▉  | 114/144 [03:47<01:00,  2.00s/it]
#
#
#
# kaktovik-ringedseal-june.tif:  80%|███████▉  | 115/144 [03:49<00:58,  2.00s/it]
#
#
#
# kaktovik-ringedseal-march.tif:  81%|████████  | 116/144 [03:51<00:56,  2.00s/it]
#
#
#
# kaktovik-ringedseal-may.tif:  81%|████████▏ | 117/144 [03:53<00:54,  2.00s/it]
#
#
#
# kaktovik-ringedseal-november.tif:  82%|████████▏ | 118/144 [03:55<00:52,  2.00s/it]
#
#
#
# kaktovik-ringedseal-october.tif:  83%|████████▎ | 119/144 [03:57<00:50,  2.00s/it]
#
#
#
# kaktovik-ringedseal-september.tif:  83%|████████▎ | 120/144 [03:59<00:48,  2.00s/it]
#
#
#
# kaktovik-walrus-april.tif:  84%|████████▍ | 121/144 [03:59<00:33,  1.45s/it]
#
#
#
# kaktovik-walrus-august.tif:  85%|████████▍ | 122/144 [04:01<00:34,  1.57s/it]
#
#
#
# kaktovik-walrus-december.tif:  85%|████████▌ | 123/144 [04:03<00:35,  1.70s/it]
#
#
#
# kaktovik-walrus-february.tif:  86%|████████▌ | 124/144 [04:05<00:35,  1.79s/it]
#
#
#
# kaktovik-walrus-january.tif:  87%|████████▋ | 125/144 [04:07<00:35,  1.85s/it]
#
#
#
# kaktovik-walrus-july.tif:  88%|████████▊ | 126/144 [04:09<00:34,  1.90s/it]
#
#
#
# kaktovik-walrus-june.tif:  88%|████████▊ | 127/144 [04:11<00:32,  1.93s/it]
#
#
#
# kaktovik-walrus-march.tif:  89%|████████▉ | 128/144 [04:13<00:31,  1.95s/it]
#
#
#
# kaktovik-walrus-may.tif:  90%|████████▉ | 129/144 [04:15<00:29,  1.97s/it]
#
#
#
# kaktovik-walrus-november.tif:  90%|█████████ | 130/144 [04:17<00:27,  1.98s/it]
#
#
#
# kaktovik-walrus-october.tif:  91%|█████████ | 131/144 [04:19<00:25,  1.99s/it]
#
#
#
# kaktovik-walrus-september.tif:  92%|█████████▏| 132/144 [04:21<00:23,  1.99s/it]
#
#
#
# kaktovik-wolfandwolverine-april.tif:  92%|█████████▏| 133/144 [04:24<00:23,  2.11s/it]
#
#
#
# kaktovik-wolfandwolverine-august.tif:  93%|█████████▎| 134/144 [04:27<00:24,  2.43s/it]
#
#
#
# kaktovik-wolfandwolverine-december.tif:  94%|█████████▍| 135/144 [04:28<00:19,  2.13s/it]
#
#
#
# kaktovik-wolfandwolverine-february.tif:  94%|█████████▍| 136/144 [04:30<00:16,  2.09s/it]
#
#
#
# kaktovik-wolfandwolverine-january.tif:  95%|█████████▌| 137/144 [04:32<00:14,  2.07s/it]
#
#
#
# kaktovik-wolfandwolverine-july.tif:  96%|█████████▌| 138/144 [04:34<00:12,  2.05s/it]
#
#
#
# kaktovik-wolfandwolverine-june.tif:  97%|█████████▋| 139/144 [04:36<00:10,  2.03s/it]
#
#
#
# kaktovik-wolfandwolverine-march.tif:  97%|█████████▋| 140/144 [04:38<00:08,  2.02s/it]
#
#
#
# kaktovik-wolfandwolverine-may.tif:  98%|█████████▊| 141/144 [04:40<00:06,  2.02s/it]
#
#
#
# kaktovik-wolfandwolverine-november.tif:  99%|█████████▊| 142/144 [04:42<00:04,  2.01s/it]
#
#
#
# kaktovik-wolfandwolverine-october.tif:  99%|█████████▉| 143/144 [04:44<00:02,  2.01s/it]
#
#
#
# kaktovik-wolfandwolverine-september.tif: 100%|██████████| 144/144 [04:46<00:00,  2.01s/it]

# %%
normalize_list('utqiagvik', utqiagvik_max)
# Out:
#   0%|          | 0/156 [00:00<?, ?it/s]
#
#
#
# utqiagvik-arcticcisco-april.tif:   1%|          | 1/156 [00:01<05:07,  1.98s/it]
#
#
#
# utqiagvik-arcticcisco-august.tif:   1%|▏         | 2/156 [00:03<05:06,  1.99s/it]
#
#
#
# utqiagvik-arcticcisco-december.tif:   2%|▏         | 3/156 [00:05<05:04,  1.99s/it]
#
#
#
# utqiagvik-arcticcisco-february.tif:   3%|▎         | 4/156 [00:07<05:03,  2.00s/it]
#
#
#
# utqiagvik-arcticcisco-january.tif:   3%|▎         | 5/156 [00:09<05:01,  2.00s/it]
#
#
#
# utqiagvik-arcticcisco-july.tif:   4%|▍         | 6/156 [00:11<04:59,  2.00s/it]
#
#
#
# utqiagvik-arcticcisco-june.tif:   4%|▍         | 7/156 [00:13<04:57,  2.00s/it]
#
#
#
# utqiagvik-arcticcisco-march.tif:   5%|▌         | 8/156 [00:15<04:56,  2.00s/it]
#
#
#
# utqiagvik-arcticcisco-may.tif:   6%|▌         | 9/156 [00:18<04:54,  2.00s/it]
#
#
#
# utqiagvik-arcticcisco-november.tif:   6%|▋         | 10/156 [00:20<04:52,  2.00s/it]
#
#
#
# utqiagvik-arcticcisco-october.tif:   7%|▋         | 11/156 [00:21<04:49,  2.00s/it]
#
#
#
# utqiagvik-arcticcisco-september.tif:   8%|▊         | 12/156 [00:24<04:48,  2.00s/it]
#
#
#
# utqiagvik-beardedseal-april.tif:   8%|▊         | 13/156 [00:26<04:46,  2.00s/it]
#
#
#
# utqiagvik-beardedseal-august.tif:   9%|▉         | 14/156 [00:28<04:44,  2.00s/it]
#
#
#
# utqiagvik-beardedseal-december.tif:  10%|▉         | 15/156 [00:30<04:42,  2.00s/it]
#
#
#
# utqiagvik-beardedseal-february.tif:  10%|█         | 16/156 [00:32<04:40,  2.00s/it]
#
#
#
# utqiagvik-beardedseal-january.tif:  11%|█         | 17/156 [00:34<04:38,  2.00s/it]
#
#
#
# utqiagvik-beardedseal-july.tif:  12%|█▏        | 18/156 [00:36<04:36,  2.00s/it]
#
#
#
# utqiagvik-beardedseal-june.tif:  12%|█▏        | 19/156 [00:38<04:34,  2.00s/it]
#
#
#
# utqiagvik-beardedseal-march.tif:  13%|█▎        | 20/156 [00:40<04:32,  2.00s/it]
#
#
#
# utqiagvik-beardedseal-may.tif:  13%|█▎        | 21/156 [00:42<04:30,  2.00s/it]
#
#
#
# utqiagvik-beardedseal-november.tif:  14%|█▍        | 22/156 [00:44<04:34,  2.05s/it]
#
#
#
# utqiagvik-beardedseal-october.tif:  15%|█▍        | 23/156 [00:46<04:24,  1.99s/it]
#
#
#
# utqiagvik-beardedseal-september.tif:  15%|█▌        | 24/156 [00:48<04:22,  1.99s/it]
#
#
#
# utqiagvik-bowhead-april.tif:  16%|█▌        | 25/156 [00:50<04:21,  2.00s/it]
#
#
#
# utqiagvik-bowhead-august.tif:  17%|█▋        | 26/156 [00:52<04:19,  2.00s/it]
#
#
#
# utqiagvik-bowhead-december.tif:  17%|█▋        | 27/156 [00:54<04:17,  2.00s/it]
#
#
#
# utqiagvik-bowhead-february.tif:  18%|█▊        | 28/156 [00:56<04:16,  2.00s/it]
#
#
#
# utqiagvik-bowhead-january.tif:  19%|█▊        | 29/156 [00:58<04:14,  2.00s/it]
#
#
#
# utqiagvik-bowhead-july.tif:  19%|█▉        | 30/156 [01:00<04:12,  2.00s/it]
#
#
#
# utqiagvik-bowhead-june.tif:  20%|█▉        | 31/156 [01:02<04:10,  2.00s/it]
#
#
#
# utqiagvik-bowhead-march.tif:  21%|██        | 32/156 [01:04<04:08,  2.00s/it]
#
#
#
# utqiagvik-bowhead-may.tif:  21%|██        | 33/156 [01:06<04:06,  2.01s/it]
#
#
#
# utqiagvik-bowhead-november.tif:  22%|██▏       | 34/156 [01:08<04:04,  2.00s/it]
#
#
#
# utqiagvik-bowhead-october.tif:  22%|██▏       | 35/156 [01:10<04:02,  2.00s/it]
#
#
#
# utqiagvik-bowhead-september.tif:  23%|██▎       | 36/156 [01:12<04:00,  2.00s/it]
#
#
#
# utqiagvik-broadwhitefish-april.tif:  24%|██▎       | 37/156 [01:14<03:58,  2.00s/it]
#
#
#
# utqiagvik-broadwhitefish-august.tif:  24%|██▍       | 38/156 [01:16<03:56,  2.00s/it]
#
#
#
# utqiagvik-broadwhitefish-december.tif:  25%|██▌       | 39/156 [01:18<03:56,  2.02s/it]
#
#
#
# utqiagvik-broadwhitefish-february.tif:  26%|██▌       | 40/156 [01:20<03:51,  2.00s/it]
#
#
#
# utqiagvik-broadwhitefish-january.tif:  26%|██▋       | 41/156 [01:22<03:49,  2.00s/it]
#
#
#
# utqiagvik-broadwhitefish-july.tif:  27%|██▋       | 42/156 [01:24<03:51,  2.03s/it]
#
#
#
# utqiagvik-broadwhitefish-june.tif:  28%|██▊       | 43/156 [01:26<03:45,  1.99s/it]
#
#
#
# utqiagvik-broadwhitefish-march.tif:  28%|██▊       | 44/156 [01:28<03:43,  1.99s/it]
#
#
#
# utqiagvik-broadwhitefish-may.tif:  29%|██▉       | 45/156 [01:30<03:41,  2.00s/it]
#
#
#
# utqiagvik-broadwhitefish-november.tif:  29%|██▉       | 46/156 [01:32<03:39,  2.00s/it]
#
#
#
# utqiagvik-broadwhitefish-october.tif:  30%|███       | 47/156 [01:34<03:38,  2.00s/it]
#
#
#
# utqiagvik-broadwhitefish-september.tif:  31%|███       | 48/156 [01:36<03:36,  2.00s/it]
#
#
#
# utqiagvik-burbot-april.tif:  31%|███▏      | 49/156 [01:38<03:48,  2.13s/it]
#
#
#
# utqiagvik-burbot-august.tif:  32%|███▏      | 50/156 [01:41<04:16,  2.42s/it]
#
#
#
# utqiagvik-burbot-december.tif:  33%|███▎      | 51/156 [01:43<03:44,  2.13s/it]
#
#
#
# utqiagvik-burbot-february.tif:  33%|███▎      | 52/156 [01:45<03:37,  2.10s/it]
#
#
#
# utqiagvik-burbot-january.tif:  34%|███▍      | 53/156 [01:47<03:32,  2.07s/it]
#
#
#
# utqiagvik-burbot-july.tif:  35%|███▍      | 54/156 [01:49<03:28,  2.05s/it]
#
#
#
# utqiagvik-burbot-june.tif:  35%|███▌      | 55/156 [01:51<03:25,  2.03s/it]
#
#
#
# utqiagvik-burbot-march.tif:  36%|███▌      | 56/156 [01:53<03:22,  2.03s/it]
#
#
#
# utqiagvik-burbot-may.tif:  37%|███▋      | 57/156 [01:55<03:19,  2.02s/it]
#
#
#
# utqiagvik-burbot-november.tif:  37%|███▋      | 58/156 [01:57<03:17,  2.01s/it]
#
#
#
# utqiagvik-burbot-october.tif:  38%|███▊      | 59/156 [01:59<03:14,  2.01s/it]
#
#
#
# utqiagvik-burbot-september.tif:  38%|███▊      | 60/156 [02:01<03:12,  2.01s/it]
#
#
#
# utqiagvik-caribou-april.tif:  39%|███▉      | 61/156 [02:03<03:10,  2.01s/it]
#
#
#
# utqiagvik-caribou-august.tif:  40%|███▉      | 62/156 [02:05<03:08,  2.01s/it]
#
#
#
# utqiagvik-caribou-december.tif:  40%|████      | 63/156 [02:07<03:06,  2.00s/it]
#
#
#
# utqiagvik-caribou-february.tif:  41%|████      | 64/156 [02:09<03:04,  2.00s/it]
#
#
#
# utqiagvik-caribou-january.tif:  42%|████▏     | 65/156 [02:11<03:02,  2.00s/it]
#
#
#
# utqiagvik-caribou-july.tif:  42%|████▏     | 66/156 [02:13<03:00,  2.00s/it]
#
#
#
# utqiagvik-caribou-june.tif:  43%|████▎     | 67/156 [02:15<02:58,  2.00s/it]
#
#
#
# utqiagvik-caribou-march.tif:  44%|████▎     | 68/156 [02:17<02:56,  2.00s/it]
#
#
#
# utqiagvik-caribou-may.tif:  44%|████▍     | 69/156 [02:19<02:54,  2.00s/it]
#
#
#
# utqiagvik-caribou-november.tif:  45%|████▍     | 70/156 [02:21<02:52,  2.00s/it]
#
#
#
# utqiagvik-caribou-october.tif:  46%|████▌     | 71/156 [02:23<02:50,  2.00s/it]
#
#
#
# utqiagvik-caribou-september.tif:  46%|████▌     | 72/156 [02:25<02:48,  2.00s/it]
#
#
#
# utqiagvik-dollyvardenchar-april.tif:  47%|████▋     | 73/156 [02:27<02:46,  2.00s/it]
#
#
#
# utqiagvik-dollyvardenchar-august.tif:  47%|████▋     | 74/156 [02:29<02:44,  2.00s/it]
#
#
#
# utqiagvik-dollyvardenchar-december.tif:  48%|████▊     | 75/156 [02:31<02:42,  2.00s/it]
#
#
#
# utqiagvik-dollyvardenchar-february.tif:  49%|████▊     | 76/156 [02:33<02:40,  2.00s/it]
#
#
#
# utqiagvik-dollyvardenchar-january.tif:  49%|████▉     | 77/156 [02:35<02:38,  2.00s/it]
#
#
#
# utqiagvik-dollyvardenchar-july.tif:  50%|█████     | 78/156 [02:37<02:36,  2.00s/it]
#
#
#
# utqiagvik-dollyvardenchar-june.tif:  51%|█████     | 79/156 [02:39<02:34,  2.00s/it]
#
#
#
# utqiagvik-dollyvardenchar-march.tif:  51%|█████▏    | 80/156 [02:41<02:32,  2.00s/it]
#
#
#
# utqiagvik-dollyvardenchar-may.tif:  52%|█████▏    | 81/156 [02:43<02:30,  2.00s/it]
#
#
#
# utqiagvik-dollyvardenchar-november.tif:  53%|█████▎    | 82/156 [02:45<02:28,  2.00s/it]
#
#
#
# utqiagvik-dollyvardenchar-october.tif:  53%|█████▎    | 83/156 [02:47<02:26,  2.00s/it]
# utqiagvik-dollyvardenchar-september.tif:  54%|█████▍    | 84/156 [02:49<02:24,  2.00s/it]
#
#
#
# utqiagvik-eider-april.tif:  54%|█████▍    | 85/156 [02:51<02:22,  2.00s/it]
#
#
#
# utqiagvik-eider-august.tif:  55%|█████▌    | 86/156 [02:53<02:20,  2.00s/it]
#
#
#
# utqiagvik-eider-december.tif:  56%|█████▌    | 87/156 [02:55<02:18,  2.00s/it]
#
#
#
# utqiagvik-eider-february.tif:  56%|█████▋    | 88/156 [02:57<02:16,  2.00s/it]
#
#
#
# utqiagvik-eider-january.tif:  57%|█████▋    | 89/156 [02:59<02:14,  2.00s/it]
#
#
#
# utqiagvik-eider-july.tif:  58%|█████▊    | 90/156 [03:01<02:12,  2.00s/it]
#
#
#
# utqiagvik-eider-june.tif:  58%|█████▊    | 91/156 [03:03<02:10,  2.00s/it]
#
#
#
# utqiagvik-eider-march.tif:  59%|█████▉    | 92/156 [03:05<02:08,  2.00s/it]
#
#
#
# utqiagvik-eider-may.tif:  60%|█████▉    | 93/156 [03:07<02:06,  2.00s/it]
#
#
#
# utqiagvik-eider-november.tif:  60%|██████    | 94/156 [03:09<02:04,  2.00s/it]
#
#
#
# utqiagvik-eider-october.tif:  61%|██████    | 95/156 [03:11<02:02,  2.00s/it]
#
#
#
# utqiagvik-eider-september.tif:  62%|██████▏   | 96/156 [03:13<02:00,  2.00s/it]
#
#
#
# utqiagvik-geese-april.tif:  62%|██████▏   | 97/156 [03:15<01:58,  2.00s/it]
#
#
#
# utqiagvik-geese-august.tif:  63%|██████▎   | 98/156 [03:17<01:56,  2.00s/it]
#
#
#
# utqiagvik-geese-december.tif:  63%|██████▎   | 99/156 [03:19<01:54,  2.00s/it]
#
#
#
# utqiagvik-geese-february.tif:  64%|██████▍   | 100/156 [03:21<01:52,  2.00s/it]
#
#
#
# utqiagvik-geese-january.tif:  65%|██████▍   | 101/156 [03:23<01:50,  2.00s/it]
#
#
#
# utqiagvik-geese-july.tif:  65%|██████▌   | 102/156 [03:25<01:48,  2.00s/it]
#
#
#
# utqiagvik-geese-june.tif:  66%|██████▌   | 103/156 [03:27<01:46,  2.01s/it]
#
#
#
# utqiagvik-geese-march.tif:  67%|██████▋   | 104/156 [03:29<01:44,  2.00s/it]
#
#
#
# utqiagvik-geese-may.tif:  67%|██████▋   | 105/156 [03:31<01:42,  2.00s/it]
#
#
#
# utqiagvik-geese-november.tif:  68%|██████▊   | 106/156 [03:33<01:40,  2.00s/it]
#
#
#
# utqiagvik-geese-october.tif:  69%|██████▊   | 107/156 [03:35<01:39,  2.03s/it]
#
#
#
# utqiagvik-geese-september.tif:  69%|██████▉   | 108/156 [03:37<01:42,  2.13s/it]
#
#
#
# utqiagvik-moose-april.tif:  70%|██████▉   | 109/156 [03:38<01:26,  1.84s/it]
#
#
#
# utqiagvik-moose-august.tif:  71%|███████   | 110/156 [03:40<01:18,  1.70s/it]
#
#
#
# utqiagvik-moose-december.tif:  71%|███████   | 111/156 [03:42<01:20,  1.79s/it]
#
#
#
# utqiagvik-moose-february.tif:  72%|███████▏  | 112/156 [03:44<01:21,  1.86s/it]
#
#
#
# utqiagvik-moose-january.tif:  72%|███████▏  | 113/156 [03:46<01:21,  1.90s/it]
#
#
#
# utqiagvik-moose-july.tif:  73%|███████▎  | 114/156 [03:48<01:21,  1.93s/it]
#
#
#
# utqiagvik-moose-june.tif:  74%|███████▎  | 115/156 [03:50<01:20,  1.95s/it]
#
#
#
# utqiagvik-moose-march.tif:  74%|███████▍  | 116/156 [03:52<01:18,  1.97s/it]
#
#
#
# utqiagvik-moose-may.tif:  75%|███████▌  | 117/156 [03:54<01:17,  1.98s/it]
#
#
#
# utqiagvik-moose-november.tif:  76%|███████▌  | 118/156 [03:56<01:15,  1.99s/it]
#
#
#
# utqiagvik-moose-october.tif:  76%|███████▋  | 119/156 [03:58<01:13,  1.99s/it]
#
#
#
# utqiagvik-moose-september.tif:  77%|███████▋  | 120/156 [04:00<01:11,  1.99s/it]
#
#
#
# utqiagvik-ringedseal-april.tif:  78%|███████▊  | 121/156 [04:02<01:09,  2.00s/it]
#
#
#
# utqiagvik-ringedseal-august.tif:  78%|███████▊  | 122/156 [04:04<01:07,  2.00s/it]
#
#
#
# utqiagvik-ringedseal-december.tif:  79%|███████▉  | 123/156 [04:06<01:05,  2.00s/it]
#
#
#
# utqiagvik-ringedseal-february.tif:  79%|███████▉  | 124/156 [04:08<01:04,  2.02s/it]
#
#
#
# utqiagvik-ringedseal-january.tif:  80%|████████  | 125/156 [04:10<01:01,  1.99s/it]
#
#
#
# utqiagvik-ringedseal-july.tif:  81%|████████  | 126/156 [04:12<00:59,  2.00s/it]
#
#
#
# utqiagvik-ringedseal-june.tif:  81%|████████▏ | 127/156 [04:14<00:57,  2.00s/it]
#
#
#
# utqiagvik-ringedseal-march.tif:  82%|████████▏ | 128/156 [04:16<00:56,  2.00s/it]
#
#
#
# utqiagvik-ringedseal-may.tif:  83%|████████▎ | 129/156 [04:18<00:54,  2.00s/it]
#
#
#
# utqiagvik-ringedseal-november.tif:  83%|████████▎ | 130/156 [04:20<00:52,  2.00s/it]
#
#
#
# utqiagvik-ringedseal-october.tif:  84%|████████▍ | 131/156 [04:22<00:50,  2.00s/it]
#
#
#
# utqiagvik-ringedseal-september.tif:  85%|████████▍ | 132/156 [04:24<00:48,  2.00s/it]
#
#
#
# utqiagvik-walrus-april.tif:  85%|████████▌ | 133/156 [04:26<00:46,  2.00s/it]
#
#
#
# utqiagvik-walrus-august.tif:  86%|████████▌ | 134/156 [04:26<00:32,  1.46s/it]
#
#
#
# utqiagvik-walrus-december.tif:  87%|████████▋ | 135/156 [04:28<00:32,  1.56s/it]
#
#
#
# utqiagvik-walrus-february.tif:  87%|████████▋ | 136/156 [04:30<00:33,  1.70s/it]
#
#
#
# utqiagvik-walrus-january.tif:  88%|████████▊ | 137/156 [04:32<00:33,  1.79s/it]
#
#
#
# utqiagvik-walrus-july.tif:  88%|████████▊ | 138/156 [04:32<00:23,  1.31s/it]
#
#
#
# utqiagvik-walrus-june.tif:  89%|████████▉ | 139/156 [04:34<00:24,  1.46s/it]
#
#
#
# utqiagvik-walrus-march.tif:  90%|████████▉ | 140/156 [04:36<00:25,  1.62s/it]
#
#
#
# utqiagvik-walrus-may.tif:  90%|█████████ | 141/156 [04:38<00:26,  1.74s/it]
#
#
#
# utqiagvik-walrus-november.tif:  91%|█████████ | 142/156 [04:40<00:25,  1.82s/it]
#
#
#
# utqiagvik-walrus-october.tif:  92%|█████████▏| 143/156 [04:42<00:24,  1.87s/it]
#
#
#
# utqiagvik-walrus-september.tif:  92%|█████████▏| 144/156 [04:44<00:22,  1.91s/it]
#
#
#
# utqiagvik-wolfandwolverine-april.tif:  93%|█████████▎| 145/156 [04:46<00:21,  1.94s/it]
#
#
#
# utqiagvik-wolfandwolverine-august.tif:  94%|█████████▎| 146/156 [04:48<00:19,  1.96s/it]
#
#
#
# utqiagvik-wolfandwolverine-december.tif:  94%|█████████▍| 147/156 [04:50<00:17,  1.97s/it]
#
#
#
# utqiagvik-wolfandwolverine-february.tif:  95%|█████████▍| 148/156 [04:52<00:15,  1.98s/it]
#
#
#
# utqiagvik-wolfandwolverine-january.tif:  96%|█████████▌| 149/156 [04:54<00:13,  1.99s/it]
#
#
#
# utqiagvik-wolfandwolverine-july.tif:  96%|█████████▌| 150/156 [04:56<00:11,  1.99s/it]
#
#
#
# utqiagvik-wolfandwolverine-june.tif:  97%|█████████▋| 151/156 [04:58<00:09,  1.99s/it]
#
#
#
# utqiagvik-wolfandwolverine-march.tif:  97%|█████████▋| 152/156 [05:00<00:07,  2.00s/it]
#
#
#
# utqiagvik-wolfandwolverine-may.tif:  98%|█████████▊| 153/156 [05:02<00:05,  2.00s/it]
#
#
#
# utqiagvik-wolfandwolverine-november.tif:  99%|█████████▊| 154/156 [05:04<00:03,  2.00s/it]
#
#
#
# utqiagvik-wolfandwolverine-october.tif:  99%|█████████▉| 155/156 [05:06<00:02,  2.00s/it]
#
#
#
# utqiagvik-wolfandwolverine-september.tif: 100%|██████████| 156/156 [05:08<00:00,  2.00s/it]

# %%
normalize_list('nuiqsut', nuiqsut_max)
# Out:
#   0%|          | 0/144 [00:00<?, ?it/s]
#
#
#
# nuiqsut-arcticcisco-april.tif:   1%|          | 1/144 [00:01<04:41,  1.97s/it]
#
#
#
# nuiqsut-arcticcisco-august.tif:   1%|▏         | 2/144 [00:03<04:41,  1.98s/it]
#
#
#
# nuiqsut-arcticcisco-december.tif:   2%|▏         | 3/144 [00:05<04:40,  1.99s/it]
#
#
#
# nuiqsut-arcticcisco-february.tif:   3%|▎         | 4/144 [00:07<04:38,  1.99s/it]
#
#
#
# nuiqsut-arcticcisco-january.tif:   3%|▎         | 5/144 [00:09<04:37,  2.00s/it]
#
#
#
# nuiqsut-arcticcisco-july.tif:   4%|▍         | 6/144 [00:11<04:35,  2.00s/it]
#
#
#
# nuiqsut-arcticcisco-june.tif:   5%|▍         | 7/144 [00:13<04:33,  2.00s/it]
#
#
#
# nuiqsut-arcticcisco-march.tif:   6%|▌         | 8/144 [00:15<04:32,  2.00s/it]
#
#
#
# nuiqsut-arcticcisco-may.tif:   6%|▋         | 9/144 [00:17<04:30,  2.00s/it]
#
#
#
# nuiqsut-arcticcisco-november.tif:   7%|▋         | 10/144 [00:19<04:27,  2.00s/it]
#
#
#
# nuiqsut-arcticcisco-october.tif:   8%|▊         | 11/144 [00:22<04:26,  2.00s/it]
#
#
#
# nuiqsut-arcticcisco-september.tif:   8%|▊         | 12/144 [00:24<04:24,  2.00s/it]
#
#
#
# nuiqsut-beardedseal-april.tif:   9%|▉         | 13/144 [00:26<04:22,  2.00s/it]
#
#
#
# nuiqsut-beardedseal-august.tif:  10%|▉         | 14/144 [00:28<04:20,  2.00s/it]
#
#
#
# nuiqsut-beardedseal-december.tif:  10%|█         | 15/144 [00:30<04:34,  2.13s/it]
#
#
#
# nuiqsut-beardedseal-february.tif:  11%|█         | 16/144 [00:33<05:09,  2.42s/it]
#
#
#
# nuiqsut-beardedseal-january.tif:  12%|█▏        | 17/144 [00:35<04:31,  2.14s/it]
#
#
#
# nuiqsut-beardedseal-july.tif:  12%|█▎        | 18/144 [00:37<04:24,  2.10s/it]
#
#
#
# nuiqsut-beardedseal-june.tif:  13%|█▎        | 19/144 [00:39<04:18,  2.07s/it]
#
#
#
# nuiqsut-beardedseal-march.tif:  14%|█▍        | 20/144 [00:41<04:14,  2.05s/it]
#
#
#
# nuiqsut-beardedseal-may.tif:  15%|█▍        | 21/144 [00:43<04:10,  2.03s/it]
#
#
#
# nuiqsut-beardedseal-november.tif:  15%|█▌        | 22/144 [00:45<04:07,  2.02s/it]
#
#
#
# nuiqsut-beardedseal-october.tif:  16%|█▌        | 23/144 [00:47<04:04,  2.02s/it]
#
#
#
# nuiqsut-beardedseal-september.tif:  17%|█▋        | 24/144 [00:49<04:01,  2.01s/it]
#
#
#
# nuiqsut-bowhead-april.tif:  17%|█▋        | 25/144 [00:51<03:59,  2.01s/it]
#
#
#
# nuiqsut-bowhead-august.tif:  18%|█▊        | 26/144 [00:53<03:57,  2.01s/it]
#
#
#
# nuiqsut-bowhead-december.tif:  19%|█▉        | 27/144 [00:55<03:54,  2.01s/it]
#
#
#
# nuiqsut-bowhead-february.tif:  19%|█▉        | 28/144 [00:57<03:52,  2.01s/it]
#
#
#
# nuiqsut-bowhead-january.tif:  20%|██        | 29/144 [00:59<03:50,  2.00s/it]
#
#
#
# nuiqsut-bowhead-july.tif:  21%|██        | 30/144 [01:01<03:48,  2.00s/it]
#
#
#
# nuiqsut-bowhead-june.tif:  22%|██▏       | 31/144 [01:03<03:46,  2.00s/it]
#
#
#
# nuiqsut-bowhead-march.tif:  22%|██▏       | 32/144 [01:05<03:44,  2.00s/it]
#
#
#
# nuiqsut-bowhead-may.tif:  23%|██▎       | 33/144 [01:07<03:42,  2.00s/it]
#
#
#
# nuiqsut-bowhead-november.tif:  24%|██▎       | 34/144 [01:09<03:40,  2.00s/it]
#
#
#
# nuiqsut-bowhead-october.tif:  24%|██▍       | 35/144 [01:11<03:38,  2.00s/it]
#
#
#
# nuiqsut-bowhead-september.tif:  25%|██▌       | 36/144 [01:13<03:36,  2.00s/it]
#
#
#
# nuiqsut-broadwhitefish-april.tif:  26%|██▌       | 37/144 [01:15<03:34,  2.00s/it]
#
#
#
# nuiqsut-broadwhitefish-august.tif:  26%|██▋       | 38/144 [01:17<03:32,  2.00s/it]
#
#
#
# nuiqsut-broadwhitefish-december.tif:  27%|██▋       | 39/144 [01:19<03:30,  2.00s/it]
#
#
#
# nuiqsut-broadwhitefish-february.tif:  28%|██▊       | 40/144 [01:21<03:28,  2.00s/it]
#
#
#
# nuiqsut-broadwhitefish-january.tif:  28%|██▊       | 41/144 [01:23<03:26,  2.00s/it]
#
#
#
# nuiqsut-broadwhitefish-july.tif:  29%|██▉       | 42/144 [01:25<03:24,  2.00s/it]
#
#
#
# nuiqsut-broadwhitefish-june.tif:  30%|██▉       | 43/144 [01:27<03:22,  2.00s/it]
#
#
#
# nuiqsut-broadwhitefish-march.tif:  31%|███       | 44/144 [01:29<03:20,  2.00s/it]
#
#
#
# nuiqsut-broadwhitefish-may.tif:  31%|███▏      | 45/144 [01:31<03:18,  2.00s/it]
#
#
#
# nuiqsut-broadwhitefish-november.tif:  32%|███▏      | 46/144 [01:33<03:16,  2.00s/it]
#
#
#
# nuiqsut-broadwhitefish-october.tif:  33%|███▎      | 47/144 [01:35<03:14,  2.00s/it]
#
#
#
# nuiqsut-broadwhitefish-september.tif:  33%|███▎      | 48/144 [01:37<03:12,  2.00s/it]
#
#
#
# nuiqsut-caribou-april.tif:  34%|███▍      | 49/144 [01:39<03:10,  2.00s/it]
#
#
#
# nuiqsut-caribou-august.tif:  35%|███▍      | 50/144 [01:41<03:08,  2.00s/it]
#
#
#
# nuiqsut-caribou-december.tif:  35%|███▌      | 51/144 [01:43<03:06,  2.00s/it]
#
#
#
# nuiqsut-caribou-february.tif:  36%|███▌      | 52/144 [01:45<03:04,  2.00s/it]
#
#
#
# nuiqsut-caribou-january.tif:  37%|███▋      | 53/144 [01:47<03:02,  2.00s/it]
#
#
#
# nuiqsut-caribou-july.tif:  38%|███▊      | 54/144 [01:49<03:00,  2.00s/it]
#
#
#
# nuiqsut-caribou-june.tif:  38%|███▊      | 55/144 [01:51<02:58,  2.00s/it]
#
#
#
# nuiqsut-caribou-march.tif:  39%|███▉      | 56/144 [01:53<02:56,  2.00s/it]
#
#
#
# nuiqsut-caribou-may.tif:  40%|███▉      | 57/144 [01:55<02:54,  2.00s/it]
#
#
#
# nuiqsut-caribou-november.tif:  40%|████      | 58/144 [01:57<02:52,  2.00s/it]
#
#
#
# nuiqsut-caribou-october.tif:  41%|████      | 59/144 [01:59<02:50,  2.00s/it]
#
#
#
# nuiqsut-caribou-september.tif:  42%|████▏     | 60/144 [02:01<02:48,  2.00s/it]
#
#
#
# nuiqsut-dollyvardenchar-april.tif:  42%|████▏     | 61/144 [02:03<02:46,  2.00s/it]
#
#
#
# nuiqsut-dollyvardenchar-august.tif:  43%|████▎     | 62/144 [02:05<02:44,  2.00s/it]
#
#
#
# nuiqsut-dollyvardenchar-december.tif:  44%|████▍     | 63/144 [02:07<02:42,  2.00s/it]
#
#
#
# nuiqsut-dollyvardenchar-february.tif:  44%|████▍     | 64/144 [02:09<02:40,  2.00s/it]
#
#
#
# nuiqsut-dollyvardenchar-january.tif:  45%|████▌     | 65/144 [02:11<02:38,  2.00s/it]
#
#
#
# nuiqsut-dollyvardenchar-july.tif:  46%|████▌     | 66/144 [02:13<02:38,  2.03s/it]
#
#
#
# nuiqsut-dollyvardenchar-june.tif:  47%|████▋     | 67/144 [02:15<02:33,  1.99s/it]
#
#
#
# nuiqsut-dollyvardenchar-march.tif:  47%|████▋     | 68/144 [02:17<02:31,  2.00s/it]
#
#
#
# nuiqsut-dollyvardenchar-may.tif:  48%|████▊     | 69/144 [02:19<02:29,  2.00s/it]
#
#
#
# nuiqsut-dollyvardenchar-november.tif:  49%|████▊     | 70/144 [02:21<02:27,  2.00s/it]
#
#
#
# nuiqsut-dollyvardenchar-october.tif:  49%|████▉     | 71/144 [02:23<02:26,  2.00s/it]
#
#
#
# nuiqsut-dollyvardenchar-september.tif:  50%|█████     | 72/144 [02:25<02:24,  2.00s/it]
#
#
#
# nuiqsut-eider-april.tif:  51%|█████     | 73/144 [02:27<02:22,  2.00s/it]
#
#
#
# nuiqsut-eider-august.tif:  51%|█████▏    | 74/144 [02:29<02:28,  2.13s/it]
#
#
#
# nuiqsut-eider-december.tif:  52%|█████▏    | 75/144 [02:32<02:47,  2.42s/it]
#
#
#
# nuiqsut-eider-february.tif:  53%|█████▎    | 76/144 [02:34<02:25,  2.14s/it]
#
#
#
# nuiqsut-eider-january.tif:  53%|█████▎    | 77/144 [02:36<02:20,  2.10s/it]
#
#
#
# nuiqsut-eider-july.tif:  54%|█████▍    | 78/144 [02:38<02:16,  2.07s/it]
#
#
#
# nuiqsut-eider-june.tif:  55%|█████▍    | 79/144 [02:40<02:13,  2.05s/it]
#
#
#
# nuiqsut-eider-march.tif:  56%|█████▌    | 80/144 [02:42<02:10,  2.04s/it]
#
#
#
# nuiqsut-eider-may.tif:  56%|█████▋    | 81/144 [02:44<02:07,  2.03s/it]
#
#
#
# nuiqsut-eider-november.tif:  57%|█████▋    | 82/144 [02:46<02:05,  2.02s/it]
#
#
#
# nuiqsut-eider-october.tif:  58%|█████▊    | 83/144 [02:48<02:02,  2.01s/it]
#
#
#
# nuiqsut-eider-september.tif:  58%|█████▊    | 84/144 [02:50<02:00,  2.01s/it]
# nuiqsut-geese-april.tif:  59%|█████▉    | 85/144 [02:52<01:58,  2.01s/it]
#
#
#
# nuiqsut-geese-august.tif:  60%|█████▉    | 86/144 [02:54<01:56,  2.01s/it]
#
#
#
# nuiqsut-geese-december.tif:  60%|██████    | 87/144 [02:56<01:54,  2.01s/it]
#
#
#
# nuiqsut-geese-february.tif:  61%|██████    | 88/144 [02:58<01:52,  2.00s/it]
#
#
#
# nuiqsut-geese-january.tif:  62%|██████▏   | 89/144 [03:00<01:50,  2.01s/it]
#
#
#
# nuiqsut-geese-july.tif:  62%|██████▎   | 90/144 [03:02<01:48,  2.00s/it]
#
#
#
# nuiqsut-geese-june.tif:  63%|██████▎   | 91/144 [03:04<01:46,  2.00s/it]
#
#
#
# nuiqsut-geese-march.tif:  64%|██████▍   | 92/144 [03:06<01:44,  2.00s/it]
#
#
#
# nuiqsut-geese-may.tif:  65%|██████▍   | 93/144 [03:08<01:42,  2.00s/it]
#
#
#
# nuiqsut-geese-november.tif:  65%|██████▌   | 94/144 [03:10<01:40,  2.00s/it]
#
#
#
# nuiqsut-geese-october.tif:  66%|██████▌   | 95/144 [03:12<01:38,  2.00s/it]
#
#
#
# nuiqsut-geese-september.tif:  67%|██████▋   | 96/144 [03:14<01:37,  2.03s/it]
#
#
#
# nuiqsut-moose-april.tif:  67%|██████▋   | 97/144 [03:16<01:33,  2.00s/it]
#
#
#
# nuiqsut-moose-august.tif:  68%|██████▊   | 98/144 [03:18<01:31,  2.00s/it]
#
#
#
# nuiqsut-moose-december.tif:  69%|██████▉   | 99/144 [03:20<01:29,  2.00s/it]
#
#
#
# nuiqsut-moose-february.tif:  69%|██████▉   | 100/144 [03:22<01:28,  2.00s/it]
#
#
#
# nuiqsut-moose-january.tif:  70%|███████   | 101/144 [03:24<01:26,  2.00s/it]
#
#
#
# nuiqsut-moose-july.tif:  71%|███████   | 102/144 [03:26<01:24,  2.00s/it]
#
#
#
# nuiqsut-moose-june.tif:  72%|███████▏  | 103/144 [03:28<01:22,  2.00s/it]
#
#
#
# nuiqsut-moose-march.tif:  72%|███████▏  | 104/144 [03:30<01:20,  2.00s/it]
#
#
#
# nuiqsut-moose-may.tif:  73%|███████▎  | 105/144 [03:32<01:18,  2.00s/it]
#
#
#
# nuiqsut-moose-november.tif:  74%|███████▎  | 106/144 [03:34<01:16,  2.00s/it]
#
#
#
# nuiqsut-moose-october.tif:  74%|███████▍  | 107/144 [03:36<01:14,  2.00s/it]
#
#
#
# nuiqsut-moose-september.tif:  75%|███████▌  | 108/144 [03:38<01:12,  2.00s/it]
#
#
#
# nuiqsut-ringedseal-april.tif:  76%|███████▌  | 109/144 [03:40<01:10,  2.00s/it]
#
#
#
# nuiqsut-ringedseal-august.tif:  76%|███████▋  | 110/144 [03:42<01:08,  2.00s/it]
#
#
#
# nuiqsut-ringedseal-december.tif:  77%|███████▋  | 111/144 [03:44<01:06,  2.00s/it]
#
#
#
# nuiqsut-ringedseal-february.tif:  78%|███████▊  | 112/144 [03:46<01:04,  2.00s/it]
#
#
#
# nuiqsut-ringedseal-january.tif:  78%|███████▊  | 113/144 [03:48<01:02,  2.00s/it]
#
#
#
# nuiqsut-ringedseal-july.tif:  79%|███████▉  | 114/144 [03:50<01:00,  2.00s/it]
#
#
#
# nuiqsut-ringedseal-june.tif:  80%|███████▉  | 115/144 [03:52<00:58,  2.00s/it]
#
#
#
# nuiqsut-ringedseal-march.tif:  81%|████████  | 116/144 [03:54<00:56,  2.00s/it]
#
#
#
# nuiqsut-ringedseal-may.tif:  81%|████████▏ | 117/144 [03:56<00:54,  2.00s/it]
#
#
#
# nuiqsut-ringedseal-november.tif:  82%|████████▏ | 118/144 [03:58<00:52,  2.00s/it]
#
#
#
# nuiqsut-ringedseal-october.tif:  83%|████████▎ | 119/144 [04:00<00:50,  2.00s/it]
#
#
#
# nuiqsut-ringedseal-september.tif:  83%|████████▎ | 120/144 [04:02<00:48,  2.00s/it]
#
#
#
# nuiqsut-walrus-april.tif:  84%|████████▍ | 121/144 [04:04<00:46,  2.00s/it]
#
#
#
# nuiqsut-walrus-august.tif:  85%|████████▍ | 122/144 [04:06<00:44,  2.00s/it]
#
#
#
# nuiqsut-walrus-december.tif:  85%|████████▌ | 123/144 [04:08<00:42,  2.00s/it]
#
#
#
# nuiqsut-walrus-february.tif:  86%|████████▌ | 124/144 [04:10<00:40,  2.00s/it]
#
#
#
# nuiqsut-walrus-january.tif:  87%|████████▋ | 125/144 [04:12<00:38,  2.00s/it]
#
#
#
# nuiqsut-walrus-july.tif:  88%|████████▊ | 126/144 [04:14<00:36,  2.00s/it]
#
#
#
# nuiqsut-walrus-june.tif:  88%|████████▊ | 127/144 [04:16<00:34,  2.00s/it]
#
#
#
# nuiqsut-walrus-march.tif:  89%|████████▉ | 128/144 [04:18<00:32,  2.00s/it]
#
#
#
# nuiqsut-walrus-may.tif:  90%|████████▉ | 129/144 [04:20<00:30,  2.00s/it]
#
#
#
# nuiqsut-walrus-november.tif:  90%|█████████ | 130/144 [04:22<00:28,  2.00s/it]
#
#
#
# nuiqsut-walrus-october.tif:  91%|█████████ | 131/144 [04:24<00:26,  2.00s/it]
#
#
#
# nuiqsut-walrus-september.tif:  92%|█████████▏| 132/144 [04:26<00:24,  2.00s/it]
#
#
#
# nuiqsut-wolfandwolverine-april.tif:  92%|█████████▏| 133/144 [04:28<00:23,  2.14s/it]
#
#
#
# nuiqsut-wolfandwolverine-august.tif:  93%|█████████▎| 134/144 [04:31<00:24,  2.42s/it]
#
#
#
# nuiqsut-wolfandwolverine-december.tif:  94%|█████████▍| 135/144 [04:33<00:19,  2.14s/it]
#
#
#
# nuiqsut-wolfandwolverine-february.tif:  94%|█████████▍| 136/144 [04:35<00:16,  2.10s/it]
#
#
#
# nuiqsut-wolfandwolverine-january.tif:  95%|█████████▌| 137/144 [04:37<00:14,  2.07s/it]
#
#
#
# nuiqsut-wolfandwolverine-july.tif:  96%|█████████▌| 138/144 [04:39<00:12,  2.05s/it]
#
#
#
# nuiqsut-wolfandwolverine-june.tif:  97%|█████████▋| 139/144 [04:41<00:10,  2.03s/it]
#
#
#
# nuiqsut-wolfandwolverine-march.tif:  97%|█████████▋| 140/144 [04:43<00:08,  2.02s/it]
#
#
#
# nuiqsut-wolfandwolverine-may.tif:  98%|█████████▊| 141/144 [04:45<00:06,  2.02s/it]
#
#
#
# nuiqsut-wolfandwolverine-november.tif:  99%|█████████▊| 142/144 [04:47<00:04,  2.01s/it]
#
#
#
# nuiqsut-wolfandwolverine-october.tif:  99%|█████████▉| 143/144 [04:49<00:02,  2.01s/it]
#
#
#
# nuiqsut-wolfandwolverine-september.tif: 100%|██████████| 144/144 [04:51<00:00,  2.01s/it]
